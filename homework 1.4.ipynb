# %%
Plot[x^3/(Exp[x]-1),{x,0,10},PlotRange->All]
# Out:
# -Graphics-

# %%
Integrate[x^3/(Exp[x]-1),{x,0,10}]
%//N
# Out:
#   4
# Pi                          10
# --- + 1000 (-10 + Log[-1 + E  ]) - 6
# 15
#
#                      -10                   -10                -10
# >    (50 PolyLog[2, E   ] + 10 PolyLog[3, E   ] + PolyLog[4, E   ])
# 6.43192

# %%
Integrate[x^3/(Exp[x]-1),{x,0,30}]
%//N
# Out:
#   4
# Pi                    30                                 -30                -30
# --- + 27000 Log[-1 + E  ] - 6 (30 (4500 + 15 PolyLog[2, E   ] + PolyLog[3, E   ]) +
# 15
#
#                    -30
# >      PolyLog[4, E   ])
# 6.49394

# %%
Integrate[x^3/(Exp[x]-1),{x,0,Infinity}]
# Out:
#   4
# Pi
# ---
# 15

# %%
Integrate[x^3/(Exp[x]-1),{x,0,∞}]
# Out:
#   4
# Pi
# ---
# 15

# %%
f[u_, M_] := 4 Pi n M/(2 Pi R T)^(3/2) Exp[-M u^2/(2 R T)] u^2
