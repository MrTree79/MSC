# %% [markdown]
# Homework 2.2：
# 面向低温下重掺杂硅的热容数据：
# {{1.27, 0.089}, {1.98, 0.167}, {2.32, 0.218}, {3.08, 0.401}, {3.5, 0.528}, {4.17, 0.788}};
# (1) 绘制分段线性插值的点线图
#
# (2) 实施分段三次Hermite插值并绘制点？

# %%
dataDSi = Import["D:\\Specific Heat of Degenerate Silicon.DAT"]
# Out:
# {{1.27, 0.089}, {1.98, 0.167}, {2.32, 0.218}, {3.08, 0.401}, {3.5, 0.528}, {4.17, 0.788}}

# %%
Show[
    ListLinePlot[dataDSi],
    ListPlot[dataDSi, PlotStyle -> Red, PlotMarkers -> Automatic]]
# Out:
# -Graphics-

# %%
Cv = Interpolation[dataDSi]
# Out:
# InterpolatingFunction[{{1.27, 4.17}}, <>]

# %%
Show[
    Plot[Cv[T],{T,1.2,4.2}],
    ListPlot[dataDSi, PlotStyle -> Red, PlotMarkers -> Automatic]]
# Out:
# InterpolatingFunction::dmval: Input value {1.20006} lies outside the range of data in the interpolating function. Extrapolation will be used.
# -Graphics-
