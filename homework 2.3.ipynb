# %% [markdown]
# 面向低温下重掺杂硅的热容数据：
# {{1.27,0.089},{1.98,0.167},{2.32,0.218}, …;
#
# (1) 自动化地将数据线性化？绘制散点图？
# (2) 对线性化的数据实施线性拟？

# %%
dataDSi = Import["D:\\Specific Heat of Degenerate Silicon.DAT"]
# Out:
# {{1.27, 0.089}, {1.98, 0.167}, {2.32, 0.218}, {3.08, 0.401}, {3.5, 0.528}, {4.17, 0.788}}

# %%
datLnDSi = Table[{dataDSi[[i]][[1]]^2,dataDSi[[i]][[2]]/dataDSi[[i]][[1]]}, {i, dataDSi//Length}]
# Out:
# {{1.6129, 0.0700787}, {3.9204, 0.0843434}, {5.3824, 0.0939655}, {9.4864, 0.130195},
#
# >   {12.25, 0.150857}, {17.3889, 0.188969}}

# %%
ListPlot[datLnDSi, PlotStyle -> {Red, PointSize[0.02]}]
# Out:
# -Graphics-

# %%
y = Fit[datLnDSi, {1, x}, x]
# Out:
# 0.0554041 + 0.00771335 x

# %%
Show[
    Plot[y,{x,0,20}],
    ListPlot[datLnDSi, PlotStyle -> {Red, PointSize[0.02]}]]
# Out:
# -Graphics-
